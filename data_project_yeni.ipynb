# %%
import requests 
r = requests.get('https://fakestoreapi.com/products')
print(r)

priv = r.json()
print(priv)
# Out:
# <Response [200]>
# ...

# %%
import pandas as pd
df = pd.DataFrame(priv)


df
# Out:
#     id                                              title   price  \
# 0    1  Fjallraven - Foldsack No. 1 Backpack, Fits 15 ...  109.95
# 1    2             Mens Casual Premium Slim Fit T-Shirts    22.30
# 2    3                                 Mens Cotton Jacket   55.99
# 3    4                               Mens Casual Slim Fit   15.99
# 4    5  John Hardy Women's Legends Naga Gold & Silver ...  695.00
# 5    6                       Solid Gold Petite Micropave   168.00
# 6    7                         White Gold Plated Princess    9.99
# 7    8  Pierced Owl Rose Gold Plated Stainless Steel D...   10.99
# 8    9  WD 2TB Elements Portable External Hard Drive -...   64.00
# 9   10  SanDisk SSD PLUS 1TB Internal SSD - SATA III 6...  109.00
# 10  11  Silicon Power 256GB SSD 3D NAND A55 SLC Cache ...  109.00
# 11  12  WD 4TB Gaming Drive Works with Playstation 4 P...  114.00
# 12  13  Acer SB220Q bi 21.5 inches Full HD (1920 x 108...  599.00
# ...

# %%
df.isnull().sum()
# Out:
# id             0
# title          0
# price          0
# description    0
# category       0
# image          0
# rating         0
# dtype: int64

# %%
df.dtypes
# Out:
# id               int64
# title              str
# price          float64
# description        str
# category           str
# image              str
# rating          object
# dtype: object

# %%
df['rate']  = df['rating'].apply(lambda a:a['rate'])

# %%
df['count'] = df['rating'].apply(lambda b:b['count'])

# %%
df.head()
# Out:
#    id                                              title   price  \
# 0   1  Fjallraven - Foldsack No. 1 Backpack, Fits 15 ...  109.95
# 1   2             Mens Casual Premium Slim Fit T-Shirts    22.30
# 2   3                                 Mens Cotton Jacket   55.99
# 3   4                               Mens Casual Slim Fit   15.99
# 4   5  John Hardy Women's Legends Naga Gold & Silver ...  695.00
#
#                                          description        category  \
# 0  Your perfect pack for everyday use and walks i...  men's clothing
# 1  Slim-fitting style, contrast raglan long sleev...  men's clothing
# 2  great outerwear jackets for Spring/Autumn/Wint...  men's clothing
# 3  The color could be slightly different between ...  men's clothing
# 4  From our Legends Collection, the Naga was insp...        jewelery
#
#                                                image  \
# 0  https://fakestoreapi.com/img/81fPKd-2AYL._AC_S...
# ...

# %%
r_users = requests.get('https://fakestoreapi.com/users')
print(r_users)


user_priv = r_users.json()
print(user_priv)
# Out:
# <Response [200]>
# ...

# %%
df_user = pd.DataFrame(user_priv)

df_user
# Out:
#                                              address  id               email  \
# 0  {'geolocation': {'lat': '-37.3159', 'long': '8...   1      john@gmail.com
# 1  {'geolocation': {'lat': '-37.3159', 'long': '8...   2  morrison@gmail.com
# 2  {'geolocation': {'lat': '40.3467', 'long': '-3...   3     kevin@gmail.com
# 3  {'geolocation': {'lat': '50.3467', 'long': '-2...   4       don@gmail.com
# 4  {'geolocation': {'lat': '40.3467', 'long': '-4...   5     derek@gmail.com
# 5  {'geolocation': {'lat': '20.1677', 'long': '-1...   6   david_r@gmail.com
# 6  {'geolocation': {'lat': '10.3456', 'long': '20...   7    miriam@gmail.com
# 7  {'geolocation': {'lat': '50.3456', 'long': '10...   8   william@gmail.com
# 8  {'geolocation': {'lat': '40.12456', 'long': '2...   9      kate@gmail.com
# 9  {'geolocation': {'lat': '30.24788', 'long': '-...  10    jimmie@gmail.com
#
#     username      password                                             name  \
# ...

# %%
df_user.dtypes
# Out:
# address     object
# id           int64
# email          str
# username       str
# password       str
# name        object
# phone          str
# __v          int64
# dtype: object

# %%
df_user['name']
# Out:
# 0           {'firstname': 'john', 'lastname': 'doe'}
# 1     {'firstname': 'david', 'lastname': 'morrison'}
# 2         {'firstname': 'kevin', 'lastname': 'ryan'}
# 3          {'firstname': 'don', 'lastname': 'romer'}
# 4       {'firstname': 'derek', 'lastname': 'powell'}
# 5      {'firstname': 'david', 'lastname': 'russell'}
# 6      {'firstname': 'miriam', 'lastname': 'snyder'}
# 7    {'firstname': 'william', 'lastname': 'hopkins'}
# 8          {'firstname': 'kate', 'lastname': 'hale'}
# 9       {'firstname': 'jimmie', 'lastname': 'klein'}
# Name: name, dtype: object

# %%
df_user['firstname'] = df_user['name'].apply(lambda a:a['firstname'])

# %%
df_user['lastname'] = df_user['name'].apply(lambda b:b['lastname'])

# %%
df.dtypes
# Out:
# id               int64
# title              str
# price          float64
# description        str
# category           str
# image              str
# rate           float64
# count            int64
# dtype: object

# %%
df_user['address'][0]
# Out:
# {'geolocation': {'lat': '-37.3159', 'long': '81.1496'},
#  'city': 'kilcoole',
#  'street': 'new road',
#  'number': 7682,
#  'zipcode': '12926-3874'}

# %%
df_user['city'] = df_user['address'].apply(lambda a:a['city'])
df_user['street'] = df_user['address'].apply(lambda a:a['street'])
df_user['number'] = df_user['address'].apply(lambda a:a['number'])
df_user['zipcode'] = df_user['address'].apply(lambda a:a['zipcode'])

# %%
df_user.duplicated().sum()
# Out:
# 0

# %%
df_user.isnull().sum()
# Out:
# id           0
# email        0
# username     0
# password     0
# phone        0
# __v          0
# firstname    0
# lastname     0
# city         0
# street       0
# number       0
# zipcode      0
# dtype: int64

# %%
r_carts = requests.get('https://fakestoreapi.com/carts')
print(r_carts)


card_priv =  r_carts.json()
print(card_priv)
# Out:
# <Response [200]>
# ...

# %%
df_carts =  pd.DataFrame(card_priv)

# %%
df_carts.dtypes
# Out:
# id           int64
# userId       int64
# date           str
# products    object
# __v          int64
# dtype: object

# %%
df_carts['products'][0]
# Out:
# [{'productId': 1, 'quantity': 4},
#  {'productId': 2, 'quantity': 1},
#  {'productId': 3, 'quantity': 6}]

# %%
df_carts = df_carts.explode('products')

# %%
df_carts.head()
# Out:
#    id  userId                      date                          products  __v
# 0   1       1  2020-03-02T00:00:00.000Z   {'productId': 1, 'quantity': 4}    0
# 0   1       1  2020-03-02T00:00:00.000Z   {'productId': 2, 'quantity': 1}    0
# 0   1       1  2020-03-02T00:00:00.000Z   {'productId': 3, 'quantity': 6}    0
# 1   2       1  2020-01-02T00:00:00.000Z   {'productId': 2, 'quantity': 4}    0
# 1   2       1  2020-01-02T00:00:00.000Z  {'productId': 1, 'quantity': 10}    0

# %%
df_carts['products'][0]
# Out:
# 0    {'productId': 1, 'quantity': 4}
# 0    {'productId': 2, 'quantity': 1}
# 0    {'productId': 3, 'quantity': 6}
# Name: products, dtype: object

# %%
df_carts['productId'] = df_carts['products'].apply(lambda x: x['productId'])
df_carts['quantity'] = df_carts['products'].apply(lambda x: x['quantity'])

# %%
df_carts.isnull().sum()
# Out:
# id           0
# userId       0
# date         0
# products     0
# __v          0
# productId    0
# quantity     0
# dtype: int64

# %%
from dotenv import load_dotenv
import os
from sqlalchemy import create_engine

load_dotenv()

DB_PASSWORD = os.getenv("DB_PASSWORD")
DATABASE_URL = f'postgresql+psycopg2://postgres:{DB_PASSWORD}@database-1.cxecw4yym81q.eu-north-1.rds.amazonaws.com:5432/postgres'
engine = create_engine(DATABASE_URL)


df_carts = df_carts.drop(columns=['products', '__v'], errors='ignore')
df = df.drop(columns='rating', errors='ignore')
df_user = df_user.drop(columns='__v', errors='ignore')

# %%
df = df.drop(columns='rating')
